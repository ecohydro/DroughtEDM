# %% [markdown]
# Here we will explore the larger picture and simplistic analogies for explaining concepts within Empirical Dynamical Modeling

# %%
from pyEDM import *
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
Simplex( dataFrame = sampleData["block_3sp"], lib = "1 99", pred = "105 190",  E = 3, showPlot = True, const_pred = True, columns = "x_t", target = "x_t")
# Out:
#    time  Observations  Predictions  Const_Predictions
# 0   107     -0.212900          NaN                NaN
# 1   108      1.140320     0.829999          -0.212900
# 2   109     -1.152276    -1.690308           1.140320
# 3   110      0.585776     0.703370          -1.152276
# 4   111      0.022673     0.208247           0.585776
# ..  ...           ...          ...                ...
# 82  189      0.148809     0.063354           0.564210
# 83  190      0.626932     0.740482           0.148809
# 84  191      0.111045    -0.018126           0.626932
# 85  192      0.896599     0.862238           0.111045
# 86  193           NaN    -0.673451           0.896599
#
# [87 rows x 4 columns]

# %% [markdown]
# 1. We want to create a figure that explains the difference between prediction skill via time series forecasting. What is the difference between a high and low rho?
