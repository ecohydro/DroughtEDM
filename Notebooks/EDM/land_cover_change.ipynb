# %%
from pyEDM import *
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import os
import geopandas as gpd
from shapely.geometry import Polygon
import rasterio
import xarray as xr
from mpl_toolkits.axes_grid1 import make_axes_locatable
import fiona
import rasterio.mask
from descartes import PolygonPatch
from rasterio.plot import show
from tqdm import tqdm
import seaborn as sns

# %%
lcs_02_15 =  '/home/rgreen/tana-spin/rgreen/DroughtEDM/Data/ESACCI-LC-L4-LCCS-Map-300m-P1Y/Resampled_05/'

# %%
lc_2002 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2002-v2.0.7.tif')).read(1)
lc_2003 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2003-v2.0.7.tif')).read(1)
lc_2004 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2004-v2.0.7.tif')).read(1)
lc_2005 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2005-v2.0.7.tif')).read(1)
lc_2006 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2006-v2.0.7.tif')).read(1)
lc_2007 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2007-v2.0.7.tif')).read(1)
lc_2008 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2008-v2.0.7.tif')).read(1)
lc_2009 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2009-v2.0.7.tif')).read(1)
lc_2010 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2010-v2.0.7.tif')).read(1)
lc_2011 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2011-v2.0.7.tif')).read(1)
lc_2012 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2012-v2.0.7.tif')).read(1)
lc_2013 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2013-v2.0.7.tif')).read(1)
lc_2014 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2014-v2.0.7.tif')).read(1)
lc_2015 = (rasterio.open(lcs_02_15 + 'EA_ESACCI-LC-L4-LCCS-Map-300m-P1Y-2015-v2.0.7.tif')).read(1)
lc_2016 = (rasterio.open('/home/rgreen/tana-spin/rgreen/DroughtEDM/Data/ESACCI_2016/EA/EA_ESACCI_LC_2016_005.tif')).read(1)

# %%
plt.imshow(lc_2002)

# %%
lc_2002_ls = lc_2002.ravel().tolist()
lc_2003_ls = lc_2003.ravel().tolist()

# %%
np.unique(lc_2002)
# Out:
# array([ 10.,  11.,  12.,  20.,  30.,  40.,  50.,  60.,  61.,  62.,  70.,
#         80.,  90., 100., 110., 120., 122., 130., 150., 151., 152., 153.,
#        160., 170., 180., 190., 200., 201., 202., 210.], dtype=float32)

# %%
a1 = np.random.randint(20, size = (4,4))
a2 = np.random.randint(20, size = (4,4))

# %%
a1
# Out:
# array([[15, 11,  5, 19],
#        [12,  9, 17,  3],
#        [16,  1, 16,  8],
#        [11, 10, 18,  2]])

# %%
a2
# Out:
# array([[11,  0,  0, 11],
#        [17, 13, 17,  7],
#        [10, 12,  7,  3],
#        [11,  8, 12, 19]])

# %%
for x, y in zip(a1,a2):
    print(x,y)
# Out:
# [15 11  5 19] [11  0  0 11]
# [12  9 17  3] [17 13 17  7]
# [16  1 16  8] [10 12  7  3]
# [11 10 18  2] [11  8 12 19]

# %%
np.in1d(a1,a2)
# Out:
# array([False,  True, False,  True,  True, False,  True,  True, False,
#        False, False,  True,  True,  True, False, False])

# %%
lc_2002_flatten = np,lc_2002.flatten()

# %%
lc_2002_flatten
# Out:
# (<module 'numpy' from '/home/rgreen/miniconda3/envs/edm/lib/python3.7/site-packages/numpy/__init__.py'>,
#  array([200., 200., 200., ..., 210., 210., 210.], dtype=float32))

# %%
lc_2003_flatten = np,lc_2002.flatten()

# %%
diff_array = [print(x, ' ',y) for x,y in zip(lc_2002_ls, lc_2003_ls)]
diff_array

# %%
def iterate_two_arrays(arr1, arr2):
    new_array=[]

    for x, y in zip(arr1, arr2):
        
        #print(x, y)
        if x = 10 and y = 10:
            z = 1
            new_array.append(z)
        else:
            new_array.append(0)
# Out:
#   File "<ipython-input-41-5f2719adef72>", line 7
#     if x = 10 and y = 10:
#          ^
# SyntaxError: invalid syntax

# %%
iterate_two_arrays(lc_2002_ls, lc)

# %% [markdown]
# Understand location of low value NDVI pixels
#
# --create map of where pixels that only have values below 0.5 occur and above 0.5

# %%
observations_tables = '/home/rgreen/tana-crunch/rgreen/crunch/DroughtEDM/Data/observations_tables/'

# %%
ndvi_orig_table = pd.read_csv(observations_tables+'ndvi_table_origT.csv', delimiter=',', engine='c', low_memory=False, index_col=[0])

# %%
ndvi_orig_table = (ndvi_orig_table-100)/100

# %%
ndvi_orig_table
# Out:
#                0         1         2         3         4         5         6  \
# 0       0.095659  0.095168  0.093700  0.095405  0.095129  0.096133  0.096523
# 1       0.096254  0.095741  0.093984  0.094987  0.094734  0.095624  0.096341
# 2       0.096051  0.095856  0.094184  0.095052  0.094622  0.095341  0.096013
# 3       0.096105  0.096176  0.094366  0.095133  0.094268  0.094989  0.096154
# 4       0.097594  0.097368  0.096698  0.097357  0.097000  0.097519  0.097690
# ...          ...       ...       ...       ...       ...       ...       ...
# 392937       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 392938       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 392939       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 392940       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 392941       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
ndvi_orig_tableT = ndvi_orig_table.T

# %%
ndvi_orig_tableT
# Out:
#        0         1         2         3         4         5         6       \
# 0    0.095659  0.096254  0.096051  0.096105  0.097594  0.097256  0.095420
# 1    0.095168  0.095741  0.095856  0.096176  0.097368  0.097023  0.095032
# 2    0.093700  0.093984  0.094184  0.094366  0.096698  0.095767  0.094419
# 3    0.095405  0.094987  0.095052  0.095133  0.097357  0.096439  0.095349
# 4    0.095129  0.094734  0.094622  0.094268  0.097000  0.096238  0.095114
# ..        ...       ...       ...       ...       ...       ...       ...
# 601  0.092024  0.092596  0.092340  0.093426  0.092701  0.091794  0.092038
# 602  0.093305  0.092845  0.093196  0.094727  0.093608  0.093117  0.092610
# 603  0.092528  0.092276  0.092053  0.091789  0.092475  0.092246  0.091963
# 604  0.092425  0.092117  0.092303  0.093443  0.092074  0.092196  0.091806
# 605  0.093018  0.092221  0.092216  0.093311  0.092106  0.092320  0.091885
#
#        7         8         9       ...  392932  392933  392934  392935  \
# ...

# %%
ndvi_orig_tableTmax = pd.DataFrame(ndvi_orig_tableT.max(), columns = {'max'})

# %%
ndvi_orig_tableTmax
# Out:
#              max
# 0       0.099490
# 1       0.102076
# 2       0.103641
# 3       0.099378
# 4       0.103537
# ...          ...
# 392937       NaN
# 392938       NaN
# 392939       NaN
# 392940       NaN
# 392941       NaN
#
# [392942 rows x 1 columns]

# %%
ndvi_orig_tableTmin = pd.DataFrame(ndvi_orig_tableT.min(), columns = {'min'})

# %%
ndvi_orig_tableTmin['threshold'] = [1 if x < 0.5 else 2 for x in ndvi_orig_tableTmin['min']]

# %%
ndvi_orig_tableTmin.loc[(ndvi_orig_tableTmin['min'].isnull()), 'threshold'] = 0

# %%
ndvi_orig_tableTmin
# Out:
#              min  threshold
# 0       0.080830          1
# 1       0.082318          1
# 2       0.082436          1
# 3       0.082417          1
# 4       0.083903          1
# ...          ...        ...
# 392937       NaN          0
# 392938       NaN          0
# 392939       NaN          0
# 392940       NaN          0
# 392941       NaN          0
#
# [392942 rows x 2 columns]

# %%
ndvi_min_threshold = np.array(ndvi_orig_tableTmin.threshold)

# %%
ndvi_min_threshold_rs = np.reshape(ndvi_min_threshold, (674, 583))

# %%
plt.imshow(ndvi_min_threshold_rs )

# %%
ndvi_orig_tableTmax['threshold'] = [1 if x < 0.5 else 2 for x in ndvi_orig_tableTmax['max']]

# %%
ndvi_orig_tableTmax
# Out:
#              max  threshold
# 0       0.099490          1
# 1       0.102076          1
# 2       0.103641          1
# 3       0.099378          1
# 4       0.103537          1
# ...          ...        ...
# 392937       NaN          2
# 392938       NaN          2
# 392939       NaN          2
# 392940       NaN          2
# 392941       NaN          2
#
# [392942 rows x 2 columns]

# %%
ndvi_orig_tableTmax.loc[(ndvi_orig_tableTmax['max'].isnull()), 'threshold'] = 0

# %%
ndvi_orig_tableTmax
# Out:
#              max  threshold
# 0       0.099490          1
# 1       0.102076          1
# 2       0.103641          1
# 3       0.099378          1
# 4       0.103537          1
# ...          ...        ...
# 392937       NaN          0
# 392938       NaN          0
# 392939       NaN          0
# 392940       NaN          0
# 392941       NaN          0
#
# [392942 rows x 2 columns]

# %%
sns.kdeplot(list(ndvi_orig_tableTmin['min']), shade=True, color = 'r', Label= 'NDVI Max')
plt.legend(loc = 2)
plt.xlabel('NDVI Max') 
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %%
sns.kdeplot(list(ndvi_orig_tableTmax['max']), shade=True, color = 'r', Label= 'NDVI Max')
plt.legend(loc = 2)
plt.xlabel('NDVI Max') 
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %%
ndvi_threshold = np.array(ndvi_orig_tableTmax.threshold)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f7ce7187f9b7> in <module>
# ----> 1 ndvi_threshold = np.array(ndvi_orig_tableTmax.threshold)
#
# NameError: name 'np' is not defined

# %%
ndvi_threshold_rs = np.reshape(ndvi_threshold, (674, 583))

# %%
plt.imshow(ndvi_threshold_rs)

# %%
def array2tiff(array, in_dir, out_dir, out_name):
    
    '''
    This function converts a 2D array into a tif using the profile of an existing tif

    '''
    

    with rasterio.open(in_dir+ os.listdir(in_dir)[0]) as src:
        profile = src.profile

    with rasterio.open(out_dir + out_name + '.tif', 'w', **profile) as dst:
        data = array
        data = data.astype(np.float32)
        #data[data<=0] = np.nan
        dst.write(data, indexes=1)

# %%
ndvi_ea = '/home/rgreen/tana-spin/rgreen/DroughtEDM/Data/eMODIS_NDVI/EA/'

# %%
array2tiff(ndvi_threshold_rs, ndvi_ea, '/home/rgreen/DroughtEDM/Data/', 'ndvi_threshold_05')

# %%
def mask_raster_shp(shp, raster, out_name, in_dir, out_dir):
    
    '''
    This function masks a raster to the shape of a smaller shapefile and creates a new raster
    
    '''
    with fiona.open(shp, "r") as shapefile:
        shapes = [feature["geometry"] for feature in shapefile]
    with rasterio.open(in_dir + raster + '.tif') as src:
        out_image, out_transform = rasterio.mask.mask(src, shapes, nodata = np.nan, crop=True)
        out_meta = src.meta

    out_meta.update({"driver": "GTiff",
                     "height": out_image.shape[1],
                     "width": out_image.shape[2],
                     "transform": out_transform})

    with rasterio.open(out_dir + out_name + '.tif', "w", **out_meta) as dest:
          
        dest.write(out_image)

# %%
Admin_boundaries = '/home/rgreen/tana-spin/rgreen/DroughtEDM/Data/AdminBoundaries/'
ea_adminbds = Admin_boundaries + 'gadm36_EastAfrica.shp'

# %%
mask_raster_shp(ea_adminbds, 'ndvi_threshold_05',  'ndvi_ea_threshold_05', '/home/rgreen/DroughtEDM/Data/', '/home/rgreen/DroughtEDM/Data/')

# %%
ndvi_ea_threshold_05 = rasterio.open('/home/rgreen/DroughtEDM/Data/ndvi_ea_threshold_05.tif')

# %%
ndvi_ea_threshold_05
# Out:
# <open DatasetReader name='/home/rgreen/DroughtEDM/Data/ndvi_ea_threshold_05.tif' mode='r'>

# %%
show(ndvi_ea_threshold_05)

# %%
lc_pixels_skill = pd.read_csv('/home/rgreen/DroughtEDM/Data/LCs_pixels/lc_pixels_skill.csv', index_col = [0])

# %%
lc_pixels_bo = list(lc_pixels_skill[lc_pixels_skill['LC']== 'woodland']['pixel_id'])
lc_pixels_ci = list(lc_pixels_skill[lc_pixels_skill['LC']== 'cropland_irrigated']['pixel_id'])
lc_pixels_cr = list(lc_pixels_skill[lc_pixels_skill['LC']== 'cropland_rainfed']['pixel_id'])
lc_pixels_gr = list(lc_pixels_skill[lc_pixels_skill['LC']== 'grassland']['pixel_id'])
lc_pixels_sh = list(lc_pixels_skill[lc_pixels_skill['LC']== 'shrubland']['pixel_id'])

# %%
ndvi_orig_bo = ndvi_orig_tableT[lc_pixels_bo]
ndvi_orig_ci = ndvi_orig_tableT[lc_pixels_ci]
ndvi_orig_cr = ndvi_orig_tableT[lc_pixels_cr]
ndvi_orig_gr = ndvi_orig_tableT[lc_pixels_gr]
ndvi_orig_sh = ndvi_orig_tableT[lc_pixels_sh]

# %%
ndvi_orig_bo_max = ndvi_orig_bo.max()
ndvi_orig_ci_max = ndvi_orig_ci.max()
ndvi_orig_cr_max = ndvi_orig_cr.max()
ndvi_orig_gr_max = ndvi_orig_gr.max()
ndvi_orig_sh_max = ndvi_orig_sh.max()

# %%
ndvi_orig_bo_range = ndvi_orig_bo.max() - ndvi_orig_bo.min()
ndvi_orig_ci_range = ndvi_orig_ci.max() - ndvi_orig_ci.min()
ndvi_orig_cr_range = ndvi_orig_cr.max() - ndvi_orig_cr.min()
ndvi_orig_gr_range = ndvi_orig_gr.max() - ndvi_orig_gr.min()
ndvi_orig_sh_range = ndvi_orig_sh.max() - ndvi_orig_sh.min()

# %%
#NDVI max by land cover
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2,3, figsize = (20,10))

sns.kdeplot(list(ndvi_orig_bo_max), shade = True, color = 'r', ax = ax1)
sns.kdeplot(list(ndvi_orig_ci_max), shade = True, color = 'r', ax = ax2)
sns.kdeplot(list(ndvi_orig_cr_max), shade = True, color = 'r', ax = ax3)
sns.kdeplot(list(ndvi_orig_gr_max), shade = True, color = 'r', ax = ax4)
sns.kdeplot(list(ndvi_orig_sh_max), shade = True, color = 'r', ax = ax5)
ax6.axis('off')

ax1.set_title('Woodland', fontsize = 20)
ax2.set_title('Cropland Irrigated', fontsize = 20)
ax3.set_title('Cropland Rainfed', fontsize = 20)
ax4.set_title('Grassland', fontsize = 20)
ax5.set_title('Shrubland', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Shrubland')

# %%
#NDVI range by land cover
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2,3, figsize = (20,10))

sns.kdeplot(list(ndvi_orig_bo_range), shade = True, color = 'r', ax = ax1)
sns.kdeplot(list(ndvi_orig_ci_range), shade = True, color = 'r', ax = ax2)
sns.kdeplot(list(ndvi_orig_cr_range), shade = True, color = 'r', ax = ax3)
sns.kdeplot(list(ndvi_orig_gr_range), shade = True, color = 'r', ax = ax4)
sns.kdeplot(list(ndvi_orig_sh_range), shade = True, color = 'r', ax = ax5)
ax6.axis('off')

ax1.set_title('Woodland', fontsize = 20)
ax2.set_title('Cropland Irrigated', fontsize = 20)
ax3.set_title('Cropland Rainfed', fontsize = 20)
ax4.set_title('Grassland', fontsize = 20)
ax5.set_title('Shrubland', fontsize = 20)
